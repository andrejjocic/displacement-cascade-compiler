# %%
import sys; sys.path.append("../src")

from compile import *
from verification_helpers import *
dsdio.set_io_objects()

handler = cfg_logging_handler() # NOTE: does logger in verification_helpers.py take precedence?
logger.setLevel(logging.INFO)

# %% [markdown]
# FIXME: always? need to restart to avoid SingletonError

# %% [markdown]
# ## signal reversal

# %%
N = 2
REVERSIBLE = True

circuit = DSDCircuit(new_toehold_generation=True)
input_signal = circuit.new_signal('X', N)
output_signal = circuit.new_signal('Y', N)
circuit.add_global(TH_EXT_NAME, 2)

circuit.add_modules([
    SignalReversal(input_signal, output_signal, reversible_design=REVERSIBLE)
], add_reporting=False)
# Out:
# WARNING - Last module is reversible. Outputs may oscillate without downstream consumption!
# WARNING - Output species not implemented for the last module; outputs not set.

# %%
dsd_path = f"../artifacts/verificiation-test/{N}-signal-reversal{'-reversible' if REVERSIBLE else ''}_WVtest.pil"
correct = verify_circuit(circuit, dsd_pil_path=dsd_path, filter_mode=CRNFilterMode.NO_FILTER)
print(f"Verification result: {'PASS' if correct else 'FAIL'}")
# Out:
# INFO - catalytic cycles represented as single formal
# WARNING - No outputs defined for the circuit; output species metadata will be empty.
# INFO - Exported PIL to ..\artifacts\signal-reversal\2-signal-reversal-reversible_WVtest.pil
# INFO - Enumeration output already exists at ../artifacts/signal-reversal/2-signal-reversal-reversible_WVtest_ENUM-CRNcond_vmax4.pil, skipping enumeration
# INFO - checking bisimulation equivalence of formal CRN (spc=6,reac=4) and 4 implementation reactions
# INFO - Divided the implementation CRN into 2 modules with [2, 2] reactions.
# INFO - Verifying module 1:
# INFO -     ReversalGate_0_1 + X0 -> e5 + Y1_from_X0
# INFO -     e5 + Y1_from_X0 -> ReversalGate_0_1 + X0
# INFO - The given system is not tidy.
# INFO -  - from initial state: ('ReversalGate_0_1', 'X0')
# INFO -     ReversalGate_0_1 + X0 -> e5 + Y1_from_X0
# INFO - Could not find formal basis: The given system is not tidy.
# INFO - bisimulation check took 0.0044384002685546875 sec
# ...

# %% [markdown]
# ## pairwise annihilation

# %%
logger.setLevel(logging.DEBUG)

# %%
N = 3
dsd_path = f"../artifacts/verification-test/{N}-PA.pil"

circuit = DSDCircuit(new_toehold_generation=True)
input_signal = circuit.new_signal('c', N)
circuit.add_global(TH_EXT_NAME, 2)

circuit.add_modules(add_reporting=False, modules=[PairwiseAnnihilation(input_signal)])

# %%
verify_circuit(circuit, dsd_pil_path=dsd_path, filter_mode=CRNFilterMode.REMOVE_ALL_SUPPORT)
# Out:
# INFO - catalytic cycles represented as single formal
# INFO - Complex C0 already has an initial concentration set; not modifying it
# INFO - Complex C1 already has an initial concentration set; not modifying it
# INFO - Complex C2 already has an initial concentration set; not modifying it
# INFO - Exported PIL to ..\artifacts\verification-test\3-PA.pil
# INFO - Enumeration output already exists at ../artifacts/verification-test/3-PA_ENUM-CRNcond_vmax4.pil, skipping enumeration
# WARNING - Updating concentration for complex 'C0' to ['initial', '628.3185307179587', 'nM'].
# WARNING - Updating concentration for complex 'C1' to ['initial', '628.3185307179587', 'nM'].
# WARNING - Updating concentration for complex 'C2' to ['initial', '628.3185307179587', 'nM'].
# WARNING - Updating concentration for complex 'Annihilator_0_1' to ['initial', '200', 'nM'].
# WARNING - Updating concentration for complex 'Annihilator_0_2' to ['initial', '200', 'nM'].
# ...

# %% [markdown]
# ## signal restoration

# %%
N = 1
dsd_path = f"../artifacts/verification-test/{N}-sig-rest.pil"

circuit = DSDCircuit()
input_signal = circuit.new_signal('in', N)
output_signal = circuit.new_signal('out', N)

circuit.add_modules(modules=[SignalRestoration(input_signal, output_signal)], add_reporting=True)

# %%
results = {}

for filter_mode in CRNFilterMode:
    for decompose_cycles in [False, True]:
        results[filter_mode, decompose_cycles] = verify_circuit(circuit, dsd_pil_path=dsd_path, filter_mode=filter_mode, decompose_cycles=decompose_cycles)

#pprint.pprint(results)
for (filter_mode, decompose_cycles), passed in results.items():
    if passed:
        print(f"Verification passed with filter_mode={filter_mode} and decompose_cycles={decompose_cycles}")
# Out:
# INFO - catalytic cycles represented as single formal
# INFO - Exported PIL to ..\artifacts\verification-test\1-sig-rest.pil
# INFO - Enumeration output already exists at ../artifacts/verification-test/1-sig-rest_ENUM-CRNcond_vmax4.pil, skipping enumeration
# INFO - checking bisimulation equivalence of formal CRN (spc=6,reac=2) and 4 implementation reactions
# INFO - Searching for bisimulation.
# INFO - Unable to satisfy delimiting condition with initial partial interpretation.
# INFO - bisimulation check took 0.0 sec
# INFO - catalytic cycles represented as several formals
# INFO - Complex Quencher_0 already has an initial concentration set; not modifying it
# INFO - Complex OUT0_from_IN0 already has an initial concentration set; not modifying it
# INFO - Exported PIL to ..\artifacts\verification-test\1-sig-rest.pil
# INFO - Enumeration output already exists at ../artifacts/verification-test/1-sig-rest_ENUM-CRNcond_vmax4.pil, skipping enumeration
# ...

# %% [markdown]
# ## reporting

# %%
N = 3
dsd_path = f"../artifacts/verification-test/{N}-reporting.pil"

circuit = DSDCircuit(new_toehold_generation=True)
input_signal = circuit.new_signal('c', N)
circuit.add_modules(add_reporting=False, modules=[Reporting(input_signal)])

verify_circuit(circuit, dsd_pil_path=dsd_path, filter_mode=CRNFilterMode.REMOVE_ALL_SUPPORT)
# Out:
# INFO - catalytic cycles represented as single formal
# INFO - Exported PIL to ..\artifacts\verification-test\3-reporting.pil
# INFO - Enumeration output already exists at ../artifacts/verification-test/3-reporting_ENUM-CRNcond_vmax4.pil, skipping enumeration
# WARNING - Updating concentration for complex 'Reporter_0' to ['initial', '200', 'nM'].
# ---------------------------------------------------------------------------
# SingletonError                            Traceback (most recent call last)
# Cell In[8], line 8
#       5 input_signal = circuit.new_signal('c', N)
#       6 circuit.add_modules(add_reporting=False, modules=[Reporting(input_signal)])
# ----> 8 verify_circuit(circuit, dsd_pil_path=dsd_path, filter_mode=CRNFilterMode.REMOVE_ALL_SUPPORT)
#
# File c:\Users\andre\fax\mag\opus\displacement-cascade-compiler\notebooks\../src\verification_helpers.py:119, in verify_circuit(circ, dsd_pil_path, filter_mode, decompose_cycles)
# ...
