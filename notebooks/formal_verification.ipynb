# %%
import sys; sys.path.append("../src")

from compile import *

# %%
handler = cfg_logging_handler() # NOTE: does logger in verification_helpers.py take precedence?
logger.setLevel(logging.INFO)

# %% [markdown]
# ## signal reversal

# %%
N = 3

circuit = DSDCircuit(new_toehold_generation=True)
input_signal = circuit.new_signal('X', N)
output_signal = circuit.new_signal('Y', N)
circuit.add_global(TH_EXT_NAME, 2)

circuit.add_modules([
    SignalReversal(input_signal, output_signal, reversible_design=False)
], add_reporting=False)
# Out:
# WARNING - Output species not implemented for the last module; outputs not set.

# %%
from verification_helpers import *

# %%
dsd_path = f"../artifacts/signal-reversal/{N}-signal-reversal_WVtest.pil"
dsdio.set_io_objects()
correct = verify_circuit(circuit, filter_mode=FuelFilterMode.NO_FILTER, decompose_cycles=False, dsd_pil_path=dsd_path)
correct
# Out:
# INFO - catalytic cycles represented as single formal
# WARNING - No outputs defined for the circuit; output species metadata will be empty.
# INFO - Exported PIL to ..\artifacts\signal-reversal\3-signal-reversal_WVtest.pil
# INFO - Enumeration output already exists at ../artifacts/signal-reversal/3-signal-reversal_WVtest_ENUM-CRNcond_vmax4.pil, skipping enumeration
# INFO - checking bisimulation equivalence of formal CRN (spc=12,reac=6) (with all species) and 6 condensed implementation reactions
# INFO - Searching for bisimulation.
# INFO - bisimulation check took 0.0020003318786621094 sec
# INFO - full interpretation: {'ReversalGate_0_1': ['ReversalGate_0_1'],
#  'ReversalGate_0_2': ['ReversalGate_0_2'],
#  'ReversalGate_1_0': ['ReversalGate_1_0'],
#  'ReversalGate_1_2': ['ReversalGate_1_2'],
#  'ReversalGate_2_0': ['ReversalGate_2_0'],
#  'ReversalGate_2_1': ['ReversalGate_2_1'],
#  'X0': ['X0'],
#  'X1': ['X1'],
#  'X2': ['X2'],
#  'Y0_from_X1': ['Y0'],
#  'Y0_from_X2': ['Y0'],
# ...

# %% [markdown]
# ## pairwise annihilation

# %%
N = 2

circuit = DSDCircuit(new_toehold_generation=True)
input_signal = circuit.new_signal('c', N)
circuit.add_global(TH_EXT_NAME, 2)

circuit.add_modules(add_reporting=False, modules=[PairwiseAnnihilation(input_signal)])

# %%
dsd_path = f"../artifacts/verification-test/{N}-PA.pil"
circuit.export_PIL(output_file=dsd_path, name_intermediates=True)
dsdio.set_io_objects()

# %%
correct = verify_circuit(circuit, filter_mode=FuelFilterMode.NO_FILTER, decompose_cycles=False, dsd_pil_path=dsd_path)
# Out:
# INFO - catalytic cycles represented as single formal
# INFO - Complex C0 already has an initial concentration set; not modifying it
# INFO - Complex C1 already has an initial concentration set; not modifying it
# INFO - Exported PIL to ..\artifacts\verification-test\2-PA.pil
# INFO - Enumeration output already exists at ../artifacts/verification-test/2-PA_ENUM-CRNcond_vmax4.pil, skipping enumeration
# WARNING - Updating concentration for complex 'C0' to ['initial', '628.3185307179587', 'nM'].
# WARNING - Updating concentration for complex 'C1' to ['initial', '628.3185307179587', 'nM'].
# WARNING - Updating concentration for complex 'Annihilator_0_1' to ['initial', '200', 'nM'].
# INFO - checking bisimulation equivalence of formal CRN (spc=3,reac=1) (with all species) and 22 condensed implementation reactions
# INFO - Searching for bisimulation.
# INFO - bisimulation check took 0.012999534606933594 sec
# NOT equivalent

# %%
correct = verify_circuit(circuit, filter_mode=FuelFilterMode.FILTER_ALL_SUPPORT, decompose_cycles=False, dsd_pil_path=dsd_path)
# Out:
# INFO - catalytic cycles represented as single formal
# INFO - Complex C0 already has an initial concentration set; not modifying it
# INFO - Complex C1 already has an initial concentration set; not modifying it
# INFO - Exported PIL to ..\artifacts\verification-test\2-PA.pil
# INFO - Enumeration output already exists at ../artifacts/verification-test/2-PA_ENUM-CRNcond_vmax4.pil, skipping enumeration
# WARNING - Updating concentration for complex 'C0' to ['initial', '628.3185307179587', 'nM'].
# WARNING - Updating concentration for complex 'C1' to ['initial', '628.3185307179587', 'nM'].
# WARNING - Updating concentration for complex 'Annihilator_0_1' to ['initial', '200', 'nM'].
# INFO - checking bisimulation equivalence of formal CRN (spc=2,reac=1) (without supporting species) and 22 condensed implementation reactions
# INFO - Searching for bisimulation.
# INFO - bisimulation check took 0.005001544952392578 sec
# INFO - full interpretation: {'C0': ['C0'],
#  'C1': ['C1'],
# ...
